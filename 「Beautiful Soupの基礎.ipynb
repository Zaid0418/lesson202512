# %%
pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4)
#   Downloading soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\tsuji\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from beautifulsoup4) (4.15.0)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
#
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    ---------------------------------------- 2/2 [beautifulsoup4]
#
# Successfully installed beautifulsoup4-4.14.3 soupsieve-2.8
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
soup = BeautifulSoup(html, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Example Page</title>
# </head>
# <body>
# <h1>Example Heading</h1>
# <p>This is an example paragraph.</p>
# <p class="example_class">This is an example paragraph with a class.</p>
# <p id="example_id">This is an example paragraph with an ID.</p>
# </body>
# </html>

# %%
from bs4 import BeautifulSoup

# %%
html = '''
<!DOCTYPE html>
<html>
<head>
<title>Example Page</title>
</head>
<body>
<h1>Example Heading</h1>
<p>This is an example paragraph.</p>
<p class="example_class">This is an example paragraph with a class.</p>
<p id="example_id">This is an example paragraph with an ID.</p>
</body>
</html>
'''

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\tsuji\appdata\local\python\pythoncore-3.14-64\lib\site-packages (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\tsuji\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\tsuji\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from bs4 import BeautifulSoup

# %%
html = '''
<!DOCTYPE html>
<html>
<head>
<title>Example Page</title>
</head>
<body>
<h1>Example Heading</h1>
<p>This is an example paragraph.</p>
<p class="example_class">This is an example paragraph with a class.</p>
<p id="example_id">This is an example paragraph with an ID.</p>
</body>
</html>
'''

# %%
soup = BeautifulSoup(html, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Example Page</title>
# </head>
# <body>
# <h1>Example Heading</h1>
# <p>This is an example paragraph.</p>
# <p class="example_class">This is an example paragraph with a class.</p>
# <p id="example_id">This is an example paragraph with an ID.</p>
# </body>
# </html>
